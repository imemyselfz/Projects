# %%
#Import all the libraries

# %%
import pandas as pd
import numpy as np

# %%
#read the csv File

# %%
df = pd.read_csv('Movies.DB-Haukinima_Faanunu.csv')

# %%
df.head()
# Out:
#    index MovieID                       Title MPAA_Rating    Budget      Gross  \
# 0      0       1          Look Who's Talking       PG-13   7500000  296000000
# 1      1       2          Driving Miss Daisy          PG   7500000  145793296
# 2      2       3              Turner & Hooch          PG  13000000   71079915
# 3      3       4  Born on the Fourth of July           R  14000000  161001698
# 4      4       5             Field of Dreams          PG  15000000   84431625
#
#   Release_Date    Genre Runtime Rating Rating_Count  \
# 0   1989-10-12  Romance      93    5.9        73638
# 1   1989-12-13   Comedy      99    7.4        91075
# 2   1989-07-28    Crime     100    7.2        91415
# 3   1989-12-20      War     145    7.2        91415
# 4   1989-04-21    Drama     107    7.5       101702
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
#Set the index of the dataset.

# %%
df.set_index("index",inplace = True)
df.head()
# Out:
#       MovieID                       Title MPAA_Rating    Budget      Gross  \
# index
# 0           1          Look Who's Talking       PG-13   7500000  296000000
# 1           2          Driving Miss Daisy          PG   7500000  145793296
# 2           3              Turner & Hooch          PG  13000000   71079915
# 3           4  Born on the Fourth of July           R  14000000  161001698
# 4           5             Field of Dreams          PG  15000000   84431625
#
#       Release_Date    Genre Runtime Rating Rating_Count  \
# index
# 0       1989-10-12  Romance      93    5.9        73638
# 1       1989-12-13   Comedy      99    7.4        91075
# 2       1989-07-28    Crime     100    7.2        91415
# 3       1989-12-20      War     145    7.2        91415
# 4       1989-04-21    Drama     107    7.5       101702
#
#                                                  Summary
# index
# 0      After a single, career-minded woman is left on...
# ...

# %%
df.shape
# Out:
# (7669, 11)

# %%
#Start the cleaning of the dataset.

# %%
#Find info about and the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7669 entries, 0 to 7668
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       7555 non-null   object
#  1   Title         7555 non-null   object
#  2   MPAA_Rating   7274 non-null   object
#  3   Budget        7272 non-null   object
#  4   Gross         2947 non-null   object
#  5   Release_Date  2701 non-null   object
#  6   Genre         3184 non-null   object
#  7   Runtime       1807 non-null   object
#  8   Rating        1201 non-null   object
#  9   Rating_Count  1982 non-null   object
#  10  Summary       634 non-null    object
# dtypes: object(11)
# memory usage: 719.0+ KB

# %%
df["MPAA_Rating"].nunique()
# Out:
# 5822

# %%
df[df["MovieID"].isnull()]
# Out:
#       MovieID Title MPAA_Rating Budget Gross Release_Date Genre Runtime  \
# index
# 7555      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7556      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7557      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7558      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7559      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# ...       ...   ...         ...    ...   ...          ...   ...     ...
# 7664      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7665      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7666      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7667      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7668      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
#
#       Rating Rating_Count Summary
# index
# 7555     NaN          NaN     NaN
# ...

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns= None

# %%
df.tail()
# Out:
#       MovieID Title MPAA_Rating Budget Gross Release_Date Genre Runtime  \
# index
# 7664      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7665      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7666      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7667      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
# 7668      NaN   NaN         NaN    NaN   NaN          NaN   NaN     NaN
#
#       Rating Rating_Count Summary
# index
# 7664     NaN          NaN     NaN
# 7665     NaN          NaN     NaN
# 7666     NaN          NaN     NaN
# 7667     NaN          NaN     NaN
# 7668     NaN          NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7669 entries, 0 to 7668
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       7555 non-null   object
#  1   Title         7555 non-null   object
#  2   MPAA_Rating   7274 non-null   object
#  3   Budget        7272 non-null   object
#  4   Gross         2947 non-null   object
#  5   Release_Date  2701 non-null   object
#  6   Genre         3184 non-null   object
#  7   Runtime       1807 non-null   object
#  8   Rating        1201 non-null   object
#  9   Rating_Count  1982 non-null   object
#  10  Summary       634 non-null    object
# dtypes: object(11)
# memory usage: 719.0+ KB

# %%
#Delete the rows that are null an create a new Dataset.

# %%
df_cl= df[df.index < 634]

# %%
df_cl.tail()
# Out:
#       MovieID                        Title MPAA_Rating     Budget      Gross  \
# index
# 629       631                      Encanto          PG  150000000  226163416
# 630       632                         Dune       PG-13  165000000  400195457
# 631       633               No Time to Die       PG-13  250000000  765199095
# 632       634             tick, tick…BOOM!       PG-13   55000000     106457
# 633       635  Venon: Let There Be Carnage       PG-13  110000000  212500000
#
#       Release_Date    Genre Runtime Rating Rating_Count  \
# index
# 629     2021-11-24   Family     109    7.3       159279
# 630     2021-10-22   Action     155    8.1       504538
# 631     2021-10-08   Action     163    7.3       323556
# 632     2021-11-12  Musical     115    7.5        82101
# 633     2021-10-01   Action     157      6       180165
#
#                                                  Summary
# index
# 629    A Colombian teenage girl has to face the frust...
# ...

# %%
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 634 entries, 0 to 633
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       634 non-null    object
#  1   Title         634 non-null    object
#  2   MPAA_Rating   634 non-null    object
#  3   Budget        634 non-null    object
#  4   Gross         634 non-null    object
#  5   Release_Date  634 non-null    object
#  6   Genre         634 non-null    object
#  7   Runtime       634 non-null    object
#  8   Rating        633 non-null    object
#  9   Rating_Count  633 non-null    object
#  10  Summary       634 non-null    object
# dtypes: object(11)
# memory usage: 59.4+ KB

# %%
df_cl["MPAA_Rating"].unique()
# Out:
# array(['PG-13', 'PG', 'R', 'G'], dtype=object)

# %%
df_cl["Genre"].nunique()
# Out:
# 17

# %%
#Change the columns datatypes to the correct ones.

# %%
df_cl["MovieID"] = df_cl["MovieID"].astype(int)
df_cl["MPAA_Rating"] = df_cl["MPAA_Rating"].astype("category")
df_cl["Budget"] = df_cl["Budget"].astype(float)
df_cl["Gross"] = df_cl["Gross"].astype(float)
df_cl["Genre"] = df_cl["Genre"].astype("category")
df_cl["Rating"] = df_cl["Rating"].astype(float)`
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\163885759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["MovieID"] = df_cl["MovieID"].astype(int)
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\163885759.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["MPAA_Rating"] = df_cl["MPAA_Rating"].astype("category")
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\163885759.py:3: SettingWithCopyWarning:
# ...

# %%
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 634 entries, 0 to 633
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       634 non-null    int32
#  1   Title         634 non-null    object
#  2   MPAA_Rating   634 non-null    category
#  3   Budget        634 non-null    float64
#  4   Gross         634 non-null    float64
#  5   Release_Date  634 non-null    object
#  6   Genre         634 non-null    category
#  7   Runtime       634 non-null    object
#  8   Rating        633 non-null    float64
#  9   Rating_Count  633 non-null    object
#  10  Summary       634 non-null    object
# dtypes: category(2), float64(3), int32(1), object(5)
# memory usage: 49.2+ KB

# %%
df_cl.head()
# Out:
#        MovieID                       Title MPAA_Rating      Budget  \
# index
# 0            1          Look Who's Talking       PG-13   7500000.0
# 1            2          Driving Miss Daisy          PG   7500000.0
# 2            3              Turner & Hooch          PG  13000000.0
# 3            4  Born on the Fourth of July           R  14000000.0
# 4            5             Field of Dreams          PG  15000000.0
#
#              Gross Release_Date    Genre Runtime  Rating Rating_Count  \
# index
# 0      296000000.0   1989-10-12  Romance      93     5.9        73638
# 1      145793296.0   1989-12-13   Comedy      99     7.4        91075
# 2       71079915.0   1989-07-28    Crime     100     7.2        91415
# 3      161001698.0   1989-12-20      War     145     7.2        91415
# 4       84431625.0   1989-04-21    Drama     107     7.5       101702
#
#                                                  Summary
# index
# 0      After a single, career-minded woman is left on...
# ...

# %%
df_cl["Release_Date"] = pd.to_datetime(df_cl["Release_Date"])
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\2949025344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["Release_Date"] = pd.to_datetime(df_cl["Release_Date"])

# %%
df_cl["Runtime"] = df_cl["Runtime"].astype(int)
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\1211317438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["Runtime"] = df_cl["Runtime"].astype(int)

# %%
df_cl.head()
# Out:
#        MovieID                       Title MPAA_Rating      Budget  \
# index
# 0            1          Look Who's Talking       PG-13   7500000.0
# 1            2          Driving Miss Daisy          PG   7500000.0
# 2            3              Turner & Hooch          PG  13000000.0
# 3            4  Born on the Fourth of July           R  14000000.0
# 4            5             Field of Dreams          PG  15000000.0
#
#              Gross Release_Date    Genre  Runtime  Rating Rating_Count  \
# index
# 0      296000000.0   1989-10-12  Romance       93     5.9        73638
# 1      145793296.0   1989-12-13   Comedy       99     7.4        91075
# 2       71079915.0   1989-07-28    Crime      100     7.2        91415
# 3      161001698.0   1989-12-20      War      145     7.2        91415
# 4       84431625.0   1989-04-21    Drama      107     7.5       101702
#
#                                                  Summary
# index
# ...

# %%
df_cl
# Out:
#        MovieID                                              Title MPAA_Rating  \
# index
# 0            1                                 Look Who's Talking       PG-13
# 1            2                                 Driving Miss Daisy          PG
# 2            3                                     Turner & Hooch          PG
# 3            4                         Born on the Fourth of July           R
# 4            5                                    Field of Dreams          PG
# 5            6                                         Uncle Buck          PG
# 6            7                            When Harry Met Sally...           R
# 7            8                                 Dead Poets Society          PG
# 8            9                                         Parenthood       PG-13
# 9           10                                    Lethal Weapon 2           R
# 10          11                               The War of the Roses           R
# ...

# %%
#Find if any columns in the new Dataset are null or not

# %%
df_cl.isnull()
# Out:
#        MovieID  Title  MPAA_Rating  Budget  Gross  Release_Date  Genre  \
# index
# 0        False  False        False   False  False         False  False
# 1        False  False        False   False  False         False  False
# 2        False  False        False   False  False         False  False
# 3        False  False        False   False  False         False  False
# 4        False  False        False   False  False         False  False
# 5        False  False        False   False  False         False  False
# 6        False  False        False   False  False         False  False
# 7        False  False        False   False  False         False  False
# 8        False  False        False   False  False         False  False
# 9        False  False        False   False  False         False  False
# 10       False  False        False   False  False         False  False
# 11       False  False        False   False  False         False  False
# ...

# %%
df_cl["Rating_Count"] = df_cl["Rating_Count"].astype(float)
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\1004287744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["Rating_Count"] = df_cl["Rating_Count"].astype(float)

# %%
df_cl[df_cl["Rating_Count"].isnull()]
# Out:
#        MovieID    Title MPAA_Rating      Budget         Gross Release_Date  \
# index
# 519        520  Minions          PG  74000000.0  1.156731e+09   2015-06-17
#
#            Genre  Runtime  Rating  Rating_Count  \
# index
# 519    Animation       91     NaN           NaN
#
#                                                  Summary
# index
# 519    Minions Stuart, Kevin, and Bob are recruited b...

# %%
#Drop the row of the dataset with even one column with null value

# %%
df_cl = df_cl.dropna(how = "any")

# %%
 #no rows are duplicated in any columns

# %%
df_cl[df_cl.duplicated()]
# Out:
# Empty DataFrame
# Columns: [MovieID, Title, MPAA_Rating, Budget, Gross, Release_Date, Genre, Runtime, Rating, Rating_Count, Summary]
# Index: []

# %%
df_cl.columns = ["ID","Title","Film_Rating","Budget","Revenue","Release_Date","Genre","Runtime","Rating","Rating_count","Summary"]
#Renaming all the columns

# %%
#Memory is optimized from 719KB to 46.6KB

# %%
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 633 entries, 0 to 633
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            633 non-null    int32
#  1   Title         633 non-null    object
#  2   Film_Rating   633 non-null    category
#  3   Budget        633 non-null    float64
#  4   Revenue       633 non-null    float64
#  5   Release_Date  633 non-null    datetime64[ns]
#  6   Genre         633 non-null    category
#  7   Runtime       633 non-null    int32
#  8   Rating        633 non-null    float64
#  9   Rating_count  633 non-null    float64
#  10  Summary       633 non-null    object
# dtypes: category(2), datetime64[ns](1), float64(4), int32(2), object(2)
# memory usage: 46.6+ KB

# %%
#Count of the number of movies in each genre

# %%
df_cl["Genre"].value_counts()
# Out:
# Action             116
# Comedy             101
# Animation           87
# Drama               67
# Thriller            41
# Science Fiction     38
# Adventure           31
# Family              30
# Romance             29
# Fantasy             28
# Crime               17
# Horror              15
# Mystery             12
# War                  9
# Western              6
# History              5
# Musical              1
# Name: Genre, dtype: int64

# %%
genres = df_cl.groupby("Genre") #Creating Genre Groups based on common values

# %%
genres.size()
# Out:
# Genre
# Action             116
# Adventure           31
# Animation           87
# Comedy             101
# Crime               17
# Drama               67
# Family              30
# Fantasy             28
# History              5
# Horror              15
# Musical              1
# Mystery             12
# Romance             29
# Science Fiction     38
# Thriller            41
# War                  9
# Western              6
# dtype: int64

# %%
#Statistic of the new Dataset.

# %%
df_cl.describe()
# Out:
#                ID        Budget       Revenue     Runtime      Rating  \
# count  633.000000  6.330000e+02  6.330000e+02  633.000000  633.000000
# mean   317.195893  9.539102e+07  4.392441e+08  119.000000    6.951501
# std    183.158849  6.790363e+07  3.420111e+08   22.353532    0.861887
# min      1.000000  6.000000e+04  1.064570e+05   79.000000    4.100000
# 25%    159.000000  4.000000e+07  2.125000e+08  102.000000    6.400000
# 50%    317.000000  8.000000e+07  3.472349e+08  117.000000    7.000000
# 75%    475.000000  1.440000e+08  5.710061e+08  133.000000    7.600000
# max    635.000000  4.000000e+08  2.796000e+09  201.000000    9.000000
#
#        Rating_count
# count  6.330000e+02
# mean   3.417207e+05
# std    3.050874e+05
# min    1.483200e+04
# 25%    1.390000e+05
# 50%    2.522230e+05
# 75%    4.453340e+05
# max    2.127228e+06

# %%
df_cl["Release_Year"] = df_cl["Release_Date"].dt.year
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\1838149844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cl["Release_Year"] = df_cl["Release_Date"].dt.year

# %%
df_cl.head(3)
# Out:
#        ID               Title Film_Rating      Budget      Revenue  \
# index
# 0       1  Look Who's Talking       PG-13   7500000.0  296000000.0
# 1       2  Driving Miss Daisy          PG   7500000.0  145793296.0
# 2       3      Turner & Hooch          PG  13000000.0   71079915.0
#
#       Release_Date    Genre  Runtime  Rating  Rating_count  \
# index
# 0       1989-10-12  Romance       93     5.9       73638.0
# 1       1989-12-13   Comedy       99     7.4       91075.0
# 2       1989-07-28    Crime      100     7.2       91415.0
#
#                                                  Summary  Release_Year
# index
# 0      After a single, career-minded woman is left on...          1989
# 1      An old Jewish woman and her African-American c...          1989
# 2      Det. Scott Turner (Tom Hanks) is an uptight, b...          1989

# %%
#ANALYSIS OF DATASET

# %%
df_cl.nlargest(n = 3, columns = "Release_Date")
#There are movies till 2021
# Out:
#         ID                  Title Film_Rating       Budget       Revenue  \
# index
# 628    630  Spiderman:No Way Home       PG-13  200000000.0  1.800000e+09
# 626    628        West Side Story       PG-13  100000000.0  7.260000e+07
# 629    631                Encanto          PG  150000000.0  2.261634e+08
#
#       Release_Date   Genre  Runtime  Rating  Rating_count  \
# index
# 628     2021-12-17  Action      148     8.7      490852.0
# 626     2021-12-10   Drama      156     7.5       14832.0
# 629     2021-11-24  Family      109     7.3      159279.0
#
#                                                  Summary  Release_Year
# index
# 628    With Spider-Man's identity now revealed, Peter...          2021
# 626    An adaptation of the 1957 musical, West Side S...          2021
# 629    A Colombian teenage girl has to face the frust...          2021

# %%
#Import the visualisation libraries like matplotlib and seaborn.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_cl["Release_Year"].value_counts()#Number of movies released per year
# Out:
# 2019    21
# 2001    21
# 1989    20
# 2004    20
# 2018    20
# 2016    20
# 2014    20
# 2013    20
# 2012    20
# 2010    20
# 2009    20
# 2008    20
# 2007    20
# 2006    20
# 1990    20
# 2005    20
# 2003    20
# 1996    20
# 1992    20
# 1994    20
# 1995    20
# 1998    20
# 2000    20
# 1997    19
# 2011    19
# 2002    19
# 1999    19
# 2015    19
# 1993    19
# 2017    19
# 1991    19
# 2020    11
# 2021     8
# Name: Release_Year, dtype: int64

# %%
#the Styles available for a plotting graph
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
#Number of Movies Rekeased per Year.

# %%
#set size for plot
plt.figure(figsize=(8,6))

plt.style.use("ggplot")
df_cl["Release_Year"].value_counts().plot(kind ="line",color ="black",marker ="o",markerfacecolor ="red")
plt.title("Number of Movies Per Year")
# Out:
# Text(0.5, 1.0, 'Number of Movies Per Year')

# %%
#Distribution of Genres.

# %%
plt.figure(figsize=(10,6))

plt.style.use("ggplot")
ax = df_cl["Genre"].value_counts().plot(kind = "barh", color="red")
plt.title("Distribution of Genres")

plt.show()

# %%
#Top five Movies Based on the Revenue generated.

# %%
df_cl.nlargest(n= 5,columns = "Revenue")
# Out:
#         ID                         Title Film_Rating       Budget  \
# index
# 625    627             Avengers: Endgame       PG-13  356000000.0
# 414    415                        Avatar       PG-13  237000000.0
# 533    534  Star Wars: The Force Awakens       PG-13  245000000.0
# 594    595        Avengers: Infinity War       PG-13  400000000.0
# 177    178                       Titanic       PG-13  200000000.0
#
#             Revenue Release_Date            Genre  Runtime  Rating  \
# index
# 625    2.796000e+09   2019-04-22           Action      181     8.4
# 414    2.787965e+09   2009-12-10        Adventure      162     7.8
# 533    2.068224e+09   2015-12-15  Science Fiction      136     7.8
# 594    2.048000e+09   2018-04-23           Action      149     8.4
# 177    1.845034e+09   1997-11-18          Romance      194     7.8
#
#        Rating_count                                            Summary  \
# index
# ...

# %%
#Total Revenue generated by each genre.

# %%
genres.sum()["Revenue"]
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\1172656660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   genres.sum()["Revenue"]
# Genre
# Action             7.201931e+10
# Adventure          1.781082e+10
# Animation          4.783577e+10
# Comedy             2.471525e+10
# Crime              3.887525e+09
# Drama              1.980240e+10
# Family             8.695930e+09
# Fantasy            2.144672e+10
# History            1.714092e+09
# Horror             3.974661e+09
# Musical            1.064570e+05
# Mystery            4.100590e+09
# Romance            1.076645e+10
# Science Fiction    1.949253e+10
# Thriller           1.624992e+10
# War                3.513383e+09
# Western            2.016067e+09
# Name: Revenue, dtype: float64

# %%
#Graph of Total Revenue generated by each Genre.

# %%
plt.figure(figsize=(10,6))

plt.style.use('classic')
genres.sum()["Revenue"].plot(kind ="bar",color = "blue", ylabel = "Revenue")
plt.title("Genre with Highest Total Revenue")

plt.show()
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\177620982.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   genres.sum()["Revenue"].plot(kind ="bar",color = "blue", ylabel = "Revenue")

# %%
#Top five highest rated Films.

# %%
df_cl.nlargest(5, columns = "Rating")[["Title","Rating"]]#5 of the highest rated films
# Out:
#                                                Title  Rating
# index
# 393                                  The Dark Knight     9.0
# 83                                  Schindler's List     8.9
# 98                                 Jurassic Park III     8.9
# 99                                      Pulp Fiction     8.9
# 287    The Lord of the Rings: The Return of the King     8.9

# %%
#Percentage of movies of a certain film rating

# %%
df_cl["Film_Rating"].value_counts(normalize=True)*100
# Out:
# PG-13    47.393365
# PG       25.908373
# R        22.432859
# G         4.265403
# Name: Film_Rating, dtype: float64

# %%
plt.figure(figsize=(10,6))

plt.style.use('fivethirtyeight')
df_cl["Film_Rating"].value_counts(normalize=True).plot(kind="pie", legend=True)
plt.title("Distribution of film ratings")

plt.show()

# %%
#Bottom five movies lowest rated movies.

# %%
df_cl.nsmallest(5, columns="Rating")[["Title","Rating"]]
# Out:
#                                       Title  Rating
# index
# 426                      The Last Airbender     4.1
# 517                    Fifty Shades of Grey     4.1
# 278                 Spy Kids 3-D: Game Over     4.2
# 413                                    2012     4.3
# 438    Alvin and the Chipmunks: Chipwrecked     4.3

# %%
df_cl.corr()
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\2672047795.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_cl.corr()
#                     ID    Budget   Revenue   Runtime    Rating  Rating_count  \
# ID            1.000000  0.575553  0.492259  0.122768  0.041800      0.195919
# Budget        0.575553  1.000000  0.687590  0.305652  0.049178      0.297606
# Revenue       0.492259  0.687590  1.000000  0.315185  0.236331      0.463076
# Runtime       0.122768  0.305652  0.315185  1.000000  0.339834      0.393128
# Rating        0.041800  0.049178  0.236331  0.339834  1.000000      0.642787
# Rating_count  0.195919  0.297606  0.463076  0.393128  0.642787      1.000000
# Release_Year  0.998940  0.555027  0.479430  0.112651  0.044008      0.196738
#
#               Release_Year
# ID                0.998940
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df_cl,vars=["Budget","Revenue"])

# %%
sns.jointplot(df_cl,x="Budget",y="Revenue",kind="hex",cmap='seismic')

# %%
sns.heatmap(df_cl.corr(),annot=True)
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_19396\2127289233.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_cl.corr(),annot=True)
# <Axes: >

# %%
#Number of films of certain Film Ratings.

# %%
df_cl["Film_Rating"].value_counts()
# Out:
# PG-13    300
# PG       164
# R        142
# G         27
# Name: Film_Rating, dtype: int64

# %%
df_cl[df_cl["Film_Rating"]=="PG-13"]["Genre"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_cl.head()
# Out:
#        ID                       Title Film_Rating      Budget      Revenue  \
# index
# 0       1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1       2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2       3              Turner & Hooch          PG  13000000.0   71079915.0
# 3       4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4       5             Field of Dreams          PG  15000000.0   84431625.0
#
#       Release_Date    Genre  Runtime  Rating  Rating_count  \
# index
# 0       1989-10-12  Romance       93     5.9       73638.0
# 1       1989-12-13   Comedy       99     7.4       91075.0
# 2       1989-07-28    Crime      100     7.2       91415.0
# 3       1989-12-20      War      145     7.2       91415.0
# 4       1989-04-21    Drama      107     7.5      101702.0
#
#                                                  Summary  Release_Year
# index
# ...

# %%
df_cl[["Film_Rating","Genre"]].value_counts()
# Out:
# Film_Rating  Genre
# PG-13        Action             90
# PG           Animation          66
# PG-13        Comedy             50
# R            Drama              28
# PG-13        Adventure          28
# R            Comedy             28
# PG-13        Science Fiction    26
#              Drama              26
# PG           Family             26
# PG-13        Thriller           25
# G            Animation          21
# PG           Comedy             20
# R            Action             19
# PG-13        Fantasy            16
# R            Thriller           15
# PG-13        Romance            15
# PG           Drama              13
# R            Horror             11
#              Crime              10
# PG           Fantasy            10
#              Science Fiction     7
#              Action              7
# R            Romance             7
#              War                 7
# PG           Romance             6
# PG-13        Mystery             5
# ...

# %%
#Film Rating and Genres of the top 50 Films with the highest revenue.

# %%
df_cl.nlargest(n=50,columns ="Revenue")[["Film_Rating","Genre"]].value_counts()
# Out:
# Film_Rating  Genre
# PG-13        Action             20
# PG           Animation           6
# PG-13        Fantasy             6
# G            Animation           3
# PG           Fantasy             3
# PG-13        Adventure           3
#              Science Fiction     3
# PG           Drama               2
# PG-13        Thriller            2
# PG           Action              1
# PG-13        Romance             1
# dtype: int64

# %%
#INSIGHTS FROM THIS DATASET

# %%
#1.The Action Genre has the highest number of movies made standing at 116 movies.
#2.Average budget of all the films in the dataset is 9.5 billion.
#3.The latest movie in this dataset was Spiderman: No Way Home.
#4.The years 2019 and 2001 had the highest numbers of movies that is 21 and the year 2021 had the lowest number of movies
   #released that is 8.
#5.The top five movies that had the largest revenue were in this order: avengers endgame,Avatar,Star wars the force awakens,
   #avengers infinity war and Titanic.
#6.The Family Genre had the highest total revenue sitting at 8.6 Billion dollars.
#7.The Musical Genre had the lowest total revenue sitting at 1.06 Million dollars.
#8.The top 5 highest rated films in order are :The dark knight,Schindler's List ,Jurassic Park III, Pulp Fiction	8.9The Lord of the Rings: The Return of the King.
#9.47.3 percent of the movies were PG-13 Rated while only 4% were G Rated films.
#10.The lowest Rated movies were in this order:The Last Airbender,Fifty Shades of Grey,Spy Kids 3-D: Game Over,2012,Alvin and the Chipmunks: Chipwrecked.
#11.The Average Budget through the jointplot is around 5-10 billion.
#12.90 Films of PG-13 are of the action genre and 0 are of animation genre.
#13.20 Films that made the highest Revenue are of PG-13 rating and of the action genre.
#14.So finally we come to the conclusion that if directors want to make a film that gives highest revenue.
    # they should make a PG-13 rated Action film.
